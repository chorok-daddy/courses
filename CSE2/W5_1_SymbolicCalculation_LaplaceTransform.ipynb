# %% [markdown]
# # 제어공학2 5주차 - Note 1
#   > ## Symbolic calculation and Laplace transform with python

# %% [markdown]
# ## Symbolic Calculation

# %% [markdown]
# ### sympy library 설치

# %%
# !pip install sympy
# Out:
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (1.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy) (1.3.0)

# %% [markdown]
# ### sympy library import

# %%
import sympy as sym

# %% [markdown]
# ### 수식이 latex 포멧으로 출력되도록 init_printing 함수 호출

# %%
sym.init_printing(use_latex='mathjax')

# %% [markdown]
# ### 변수를 symbol로 선언하고, 다항식 표현하기

# %%
x, y, z = sym.symbols('x y z')
( 5*x**3 - x**2 + 3*x - 1 ) + ( -x**3 + 2*x**2 + 5 )
# Out:
#    3    2
# 4⋅x  + x  + 3⋅x + 4

# %% [markdown]
# ### 다항식을 변수에 저장하기

# %%
A = -3*x*y + x**2 + 2*y**2 + x
B = ( x**2 + x - 2 ) * ( 3*x - 1 )
A, B
# Out:
# ⎛ 2                  2            ⎛ 2        ⎞⎞
# ⎝x  - 3⋅x⋅y + x + 2⋅y , (3⋅x - 1)⋅⎝x  + x - 2⎠⎠

# %% [markdown]
# ### 다항식을 symbol 'x'를 기준으로 정리하기

# %%
sym.collect( A, x )
# Out:
#  2                    2
# x  + x⋅(1 - 3⋅y) + 2⋅y

# %% [markdown]
# ### 다항식을 전개하기

# %%
sym.expand(B)
# Out:
#    3      2
# 3⋅x  + 2⋅x  - 7⋅x + 2

# %% [markdown]
# ### 인수분해가 가능한 다항식을 C에 입력하기

# %%
C = 2*x**2 + 5*x*y + 3*y**2 + 3*x + 5*y - 2
C
# Out:
#    2                    2
# 2⋅x  + 5⋅x⋅y + 3⋅x + 3⋅y  + 5⋅y - 2

# %% [markdown]
# ### 다항식 C를 인수분해하기

# %%
sym.factor(C)
# Out:
# (x + y + 2)⋅(2⋅x + 3⋅y - 1)

# %% [markdown]
# ### 분수 형태의 다항식을 D에 입력하기

# %%
D = ( x**2 - 2*x + 1 ) / ( x**2 - 3*x + 2 )
D
# Out:
#  2
# x  - 2⋅x + 1
# ────────────
#  2
# x  - 3⋅x + 2

# %% [markdown]
# ### 분모 분자를 인수분해 후 소거 가능한 항 소거하기

# %%
sym.cancel(D)
# Out:
# x - 1
# ─────
# x - 2

# %% [markdown]
# ### 분수의 덧셈 형태의 다항식을 E에 입력하기

# %%
E = 1/(x-1) + 2/(x+2)
E
# Out:
#   2       1
# ───── + ─────
# x + 2   x - 1

# %% [markdown]
# ### 통분 후 소거 가능한 항 소거하기

# %%
sym.cancel(E)
# Out:
#    3⋅x
# ──────────
#  2
# x  + x - 2

# %% [markdown]
# ### 문자 언더바 '_' >> 직전 출력을 의미

# %%
sym.factor(_)
# Out:
#       3⋅x
# ───────────────
# (x - 1)⋅(x + 2)

# %% [markdown]
# ### 매우 복잡한 형태의 다항식을 F에 입력하기

# %%
F = ( x - 1 + 1/(x-1) ) / ( x - 1 - 1/(x-1) )
F
# Out:
#           1
# x - 1 + ─────
#         x - 1
# ─────────────
#           1
# x - 1 - ─────
#         x - 1

# %% [markdown]
# ### 복잡한 다항식을 가능한 한 간단하게 정리하기

# %%
sym.simplify(F)
# Out:
#  2
# x  - 2⋅x + 2
# ────────────
#  x⋅(x - 2)

# %% [markdown]
# ## Laplace Transform

# %% [markdown]
# ### Laplace transform에서 활용할 변수 t, s를 symbol로 선언하고 함수 f 정의하기

# %%
t, s = sym.symbols('t, s')
a = sym.symbols('a', real=True, positive=True)
f = sym.exp(-a*t)
f
# Out:
# exp(-a*t)

# %% [markdown]
# ### Laplace transform 하기

# %%
F = sym.laplace_transform(f, t, s)
F
# Out:
# ⎛  1            ⎞
# ⎜─────, -a, True⎟
# ⎝a + s          ⎠

# %% [markdown]
# ### Laplace transform이 가능한 조건 출력을 생략하기

# %%
F = sym.laplace_transform(f, t, s, noconds=True)
F
# Out:
#   1
# ─────
# a + s

# %% [markdown]
# ### Laplace transform을 간소하게 처리할 수 있도록 함수 정의하기

# %%
def L(f):
    return sym.laplace_transform(f, t, s, noconds=True)

def invL(F):
    return sym.inverse_laplace_transform(F, s, t)

# %%
L(f)
# Out:
#   1
# ─────
# a + s

# %%
invL(F)
# Out:
#  -a⋅t
# ℯ    ⋅θ(t)

# %% [markdown]
# ### $\theta(t)$는 unit step function을 의미한다

# %%
sym.Heaviside(t)
# Out:
# θ(t)

# %%
sym.plot(sym.Heaviside(t), xlim=(-1, 3), ylim=(0, 1.5))

# %% [markdown]
# ### 함수 내 변수에 특정 숫자를 대입하는 방법

# %%
invL(F).subs({a: 2})
# Out:
#  -2⋅t
# ℯ    ⋅θ(t)

# %% [markdown]
# ### 다양한 함수를 Laplace transform 해보기

# %%
omega = sym.symbols('omega', real=True)
theta = sym.Function('theta')(t)
exp = sym.exp
sin = sym.sin
cos = sym.cos
functions = [1,
         t,
         exp(-a*t),
         t*exp(-a*t),
         t**2*exp(-a*t),
         sin(omega*t),
         cos(omega*t),
         1 - exp(-a*t),
         exp(-a*t)*sin(omega*t),
         exp(-a*t)*cos(omega*t),
         sym.diff(theta,t)
         ]
functions
# Out:
# [1,
#  t,
#  exp(-a*t),
#  t*exp(-a*t),
#  t**2*exp(-a*t),
#  sin(omega*t),
#  cos(omega*t),
#  1 - exp(-a*t),
#  exp(-a*t)*sin(omega*t),
#  exp(-a*t)*cos(omega*t),
#  Derivative(theta(t), t)]

# %% [markdown]
# ### 다양한 함수를 inverse Laplace transform 해보기

# %%
L(sym.diff(theta,t)).subs({theta.subs({t:0}):0})
# Out:
# s*LaplaceTransform(theta(t), t, s)

# %%
Fs = [L(f) for f in functions]
Fs
# Out:
# [1/s,
#  s**(-2),
#  1/(a + s),
#  (a + s)**(-2),
#  2/(a + s)**3,
#  omega/(omega**2 + s**2),
#  s/(omega**2 + s**2),
#  -1/(a + s) + 1/s,
#  omega/(omega**2 + (a + s)**2),
#  (a + s)/(omega**2 + (a + s)**2),
#  s*LaplaceTransform(theta(t), t, s) - theta(0)]
