# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab\ Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone https://github.com/chorok-leader/branch-tutorial.git
# Out:
# Cloning into 'branch-tutorial'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (4/4), done.

# %%
cd branch-tutorial/
# Out:
# /content/drive/My Drive/Colab Notebooks/branch-tutorial

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/Colab Notebooks/branch-tutorial/.git/

# %%
# !git config --global user.email "kblee@kw.ac.kr"
# !git config --global user.name "chorok-daddy"

# %%
# !git checkout -b branch-tutorial-branch1
# Out:
# Switched to a new branch 'branch-tutorial-branch1'

# %%
# !git status
# Out:
# On branch branch-tutorial-branch1
# nothing to commit, working tree clean

# %%
# !git branch
# Out:
# * branch-tutorial-branch1
#   main

# %%
# !git remote add branch-tutorial https://chorok-daddy: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@github.com/chorok-leader/branch-tutorial.git

# %%
# !git add .

# %%
# !git commit -m "create branch"
# Out:
# On branch branch-tutorial-branch1
# nothing to commit, working tree clean

# %%
# !git push branch-tutorial branch-tutorial-branch1
# Out:
# Total 0 (delta 0), reused 0 (delta 0)
# remote:
# remote: Create a pull request for 'branch-tutorial-branch1' on GitHub by visiting:
# remote:      https://github.com/chorok-leader/branch-tutorial/pull/new/branch-tutorial-branch1
# remote:
# To https://github.com/chorok-leader/branch-tutorial.git
#  * [new branch]      branch-tutorial-branch1 -> branch-tutorial-branch1
