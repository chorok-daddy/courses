# %% [markdown]
# ### 1. 원격 Repository로부터 Local로 동기화하기

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Colab\ Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
# !git clone "https://github.com/chorok-daddy/repository-basic.git"
# Out:
# Cloning into 'repository-basic'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (3/3), done.

# %%
cd repository-basic/
# Out:
# /content/drive/My Drive/Colab Notebooks/repository-basic

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/drive/My Drive/Colab Notebooks/repository-basic/.git/

# %%
# !git config --global user.email "이메일 주소"
# !git config --global user.name "username"

# %% [markdown]
# ### 2. Local에서 수정하기
#
# * 수정은 Google Drive에서 chrome extension을 활용해 간단히 해볼 수 있다.

# %% [markdown]
# ### 3. Local에서 Commit 하기

# %%
# !git add .
# !git commit -m "Edit Readme.md"
# Out:
# [main 10e840d] Edit Readme.md
#  1 file changed, 8 insertions(+), 1 deletion(-)

# %%
# !git log

# %% [markdown]
# ### 4. Github 계정 token 발급하기
# * Github - settings - developer settings - personal access tokens
# * 토큰을 발급받은 후 개인적인 공간에 저장해 둔다

# %% [markdown]
# ### 5. Remote Repository로 Push
# * !git remote add [nickname] https://[username]:[token]@github.com/[repository주소]

# %%
# !git remote add repo-basic https://username:token@github.com/chorok-daddy/repository-basic.git

# %%
# !git push -u repo-basic main
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (2/2), done.
# Writing objects: 100% (3/3), 399 bytes | 133.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/chorok-daddy/repository-basic.git
#    1bcbdc2..10e840d  main -> main
# Branch 'main' set up to track remote branch 'main' from 'repo-basic'.
