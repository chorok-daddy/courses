# %% [markdown]
# ### 플랫폼(OS) 확인

# %%
import platform
platform.platform()

# %% [markdown]
# ### 하드웨어 사양 확인

# %%
# !cat /proc/cpuinfo

# %%
# !cat /proc/meminfo

# %%
# !df -h

# %% [markdown]
# ### Python 버전 확인

# %%
# !python --version

# %% [markdown]
# ### 런타임 유형 변경 (런타임 >> 런타임유형변경)

# %% [markdown]
# ### GPU 확인

# %%
# !nvidia-smi

# %% [markdown]
# ### Colab-Drive Mount

# %%
from google.colab import drive
drive.mount('/content/drive')
